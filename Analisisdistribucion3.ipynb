# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaP05/Distribuciones3/blob/main/Analisisdistribucion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import plotly.express as px
# Instala gdown para descargar archivos de Google Drive
# !pip install gdown

# Obtén el enlace para compartir de tu archivo y reemplaza 'YOUR_FILE_ID'
file_id = '1XHmylmQS9P3NJ-71GviyRaNH2R6WQ8jq'
file_path = f'https://drive.google.com/uc?id={file_id}'

# Descarga el archivo
# !gdown {file_path}

# !ls


# Reemplaza 'nombre_real_del_archivo.csv' con el nombre real del archivo descargado
datos_descargados = 'datos_descargados.csv'
df = pd.read_csv(datos_descargados)  # Use the variable 'nombre_del_archivo' here

# Print the column names to verify if 'death_event' exists and check for typos
print(df.columns)

columnas_eliminar = ['DEATH_EVENT', 'categoria_edad']  # Ajusta según tus necesidades
X = df.drop(columns=columnas_eliminar).values  # Convertir a numpy array

# Paso 2: Aplicar t-SNE
X_embedded = TSNE(n_components=3, learning_rate='auto', init='random', perplexity=3).fit_transform(X)

# Convertir DEATH_EVENT a un array unidimensional
y = df['DEATH_EVENT'].values

# Crear DataFrame para Plotly
df_plotly = pd.DataFrame({
    'TSNE1': X_embedded[:, 0],
    'TSNE2': X_embedded[:, 1],
    'TSNE3': X_embedded[:, 2],
    'DEATH_EVENT': y
})

# Asignar colores a las clases
color_map = {0: 'blue', 1: 'red'}  # Vivo: azul, Muerto: rojo
df_plotly['color'] = df_plotly['DEATH_EVENT'].map(color_map)

# Crear gráfico de dispersión 3D con Plotly
fig = px.scatter_3d(df_plotly, x='TSNE1', y='TSNE2', z='TSNE3', color='color', symbol='DEATH_EVENT',
                    symbol_map={0: 'circle', 1: 'circle-open'}, opacity=0.8,
                    title='Visualización 3D con t-SNE - Clasificación de DEATH_EVENT')
fig.update_layout(scene=dict(
                    xaxis_title='TSNE1',
                    yaxis_title='TSNE2',
                    zaxis_title='TSNE3'))
fig.show()
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1XHmylmQS9P3NJ-71GviyRaNH2R6WQ8jq
# To: /content/datos_descargados.csv
# 100% 12.2k/12.2k [00:00<00:00, 17.5MB/s]
# datos_descargados.csv  sample_data
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-957f0a1bbf7e> in <cell line: 26>()
#      24
#      25 columnas_eliminar = ['DEATH_EVENT', 'categoria_edad']  # Ajusta según tus necesidades
# ---> 26 X = df.drop(columns=columnas_eliminar).values  # Convertir a numpy array
#      27
#      28 # Paso 2: Aplicar t-SNE
#
# ...

# %%
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import plotly.express as px
# Instala gdown para descargar archivos de Google Drive
# !pip install gdown

# Obtén el enlace para compartir de tu archivo y reemplaza 'YOUR_FILE_ID'
file_id = '1XHmylmQS9P3NJ-71GviyRaNH2R6WQ8jq'
file_path = f'https://drive.google.com/uc?id={file_id}'

# Descarga el archivo
# !gdown {file_path}

# !ls


# Reemplaza 'nombre_real_del_archivo.csv' con el nombre real del archivo descargado
datos_descargados = 'datos_descargados.csv'
df = pd.read_csv(datos_descargados)  # Use the variable 'nombre_del_archivo' here

# Print the column names to verify if 'death_event' exists and check for typos
print(df.columns)

# Verify the column names and adjust the list accordingly
columnas_eliminar = ['DEATH_EVENT']  # Removed 'categoria_edad' as it's not in the DataFrame
X = df.drop(columns=columnas_eliminar).values  # Convertir a numpy array

# Paso 2: Aplicar t-SNE
X_embedded = TSNE(n_components=3, learning_rate='auto', init='random', perplexity=3).fit_transform(X)

# Convertir DEATH_EVENT a un array unidimensional
y = df['DEATH_EVENT'].values

# Crear DataFrame para Plotly
df_plotly = pd.DataFrame({
    'TSNE1': X_embedded[:, 0],
    'TSNE2': X_embedded[:, 1],
    'TSNE3': X_embedded[:, 2],
    'DEATH_EVENT': y
})

# Asignar colores a las clases
color_map = {0: 'blue', 1: 'red'}  # Vivo: azul, Muerto: rojo
df_plotly['color'] = df_plotly['DEATH_EVENT'].map(color_map)

# Crear gráfico de dispersión 3D con Plotly
fig = px.scatter_3d(df_plotly, x='TSNE1', y='TSNE2', z='TSNE3', color='color', symbol='DEATH_EVENT',
                    symbol_map={0: 'circle', 1: 'circle-open'}, opacity=0.8,
                    title='Visualización 3D con t-SNE - Clasificación de DEATH_EVENT')
fig.update_layout(scene=dict(
                    xaxis_title='TSNE1',
                    yaxis_title='TSNE2',
                    zaxis_title='TSNE3'))
fig.show()
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1XHmylmQS9P3NJ-71GviyRaNH2R6WQ8jq
# To: /content/datos_descargados.csv
# 100% 12.2k/12.2k [00:00<00:00, 24.8MB/s]
# datos_descargados.csv  sample_data
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
